# %% [markdown]
# <a href="https://colab.research.google.com/github/rushikeshnaik779/EDA/blob/master/TitanicMurderByIce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os 
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"

# %%
# %cd /content/gdrive/MyDrive/Kaggle
# Out:
# /content/gdrive/MyDrive/Kaggle

# %%
# !kaggle competitions download -c titanic
# Out:
# ...
#   0% 0.00/3.18k [00:00<?, ?B/s]
# 100% 3.18k/3.18k [00:00<00:00, 500kB/s]
# ...
#   0% 0.00/59.8k [00:00<?, ?B/s]
# 100% 59.8k/59.8k [00:00<00:00, 8.02MB/s]
# ...
#   0% 0.00/28.0k [00:00<?, ?B/s]
# 100% 28.0k/28.0k [00:00<00:00, 4.00MB/s]

# %%
# !unzip \*.zip && rm *.zip
# Out:
# unzip:  cannot find or open *.zip, *.zip.zip or *.zip.ZIP.
#
# No zipfiles found.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
# %ls
# Out:
# gender_submission.csv  kaggle.json  test.csv  train.csv

# %%
data = pd.read_csv('./train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
data.isnull().sum() # checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Question comes how many survived  

f, ax = plt.subplots(1, 2, figsize=(18, 8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1], autopct = '%1.1f%%',
                                         ax=ax[0], shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=data, ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
# Analysing the features
#SEX ---> CATEGORICAL FEATURE

data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 8))
data[['Sex', 'Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
# PCLASS ---> Ordinal feature

pd.crosstab(data.Pclass, data.Survived, margins=True).style.background_gradient(
    cmap='summer_r'
)
# Out:
# <style  type="text/css" >
# #T_898f1740_46c5_11eb_a6f0_0242ac1c0002row0_col0,#T_898f1740_46c5_11eb_a6f0_0242ac1c0002row1_col1,#T_898f1740_46c5_11eb_a6f0_0242ac1c0002row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_898f1740_46c5_11eb_a6f0_0242ac1c0002row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_898f1740_46c5_11eb_a6f0_0242ac1c0002row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_898f1740_46c5_11eb_a6f0_0242ac1c0002row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_898f1740_46c5_11eb_a6f0_0242ac1c0002row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_898f1740_46c5_11eb_a6f0_0242ac1c0002row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_898f1740_46c5_11eb_a6f0_0242ac1c0002row2_col2{
# ...

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
data['Pclass'].value_counts().plot.bar(ax=ax[0])
ax[0].set_title('Number of passengers by pclass')
ax[0].set_ylabel('Count')

sns.countplot('Pclass', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead')
# Out:
# Text(0.5, 1.0, 'Pclass: Survived vs Dead')

# %%
pd.crosstab([data.Sex, data.Survived], data.Pclass,
            margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_bb61460c_46c6_11eb_a6f0_0242ac1c0002row0_col0,#T_bb61460c_46c6_11eb_a6f0_0242ac1c0002row0_col1,#T_bb61460c_46c6_11eb_a6f0_0242ac1c0002row0_col3,#T_bb61460c_46c6_11eb_a6f0_0242ac1c0002row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_bb61460c_46c6_11eb_a6f0_0242ac1c0002row0_col2,#T_bb61460c_46c6_11eb_a6f0_0242ac1c0002row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_bb61460c_46c6_11eb_a6f0_0242ac1c0002row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_bb61460c_46c6_11eb_a6f0_0242ac1c0002row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_bb61460c_46c6_11eb_a6f0_0242ac1c0002row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_bb61460c_46c6_11eb_a6f0_0242ac1c0002row2_col0{
#             background-color:  #a7d366;
# ...

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=data)
plt.show()

# %%
# AGE ---> Continous Feature

print('Oldest Passenger was of:', data['Age'].max(), 'Years')
print('Youngest Passenger was of:', data['Age'].min(), 'Years')
print('Average Age on the ship was : ',data['Age'].mean(), 'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship was :  29.69911764705882 Years

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 8))
sns.violinplot("Pclass", "Age", hue="Survived", data=data, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))

sns.violinplot("Sex", "Age", hue="Survived", data=data,
               split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %%
data['Initial'] = 0
for i in data:
  data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')

# %%
data.Initial.value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Mlle          2
# Col           2
# Capt          1
# Sir           1
# Mme           1
# Jonkheer      1
# Don           1
# Lady          1
# Countess      1
# Ms            1
# Name: Initial, dtype: int64

# %%
pd.crosstab(data.Initial, data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row0_col0,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row0_col1,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row0_col3,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row0_col4,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row0_col5,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row0_col7,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row0_col8,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row0_col12,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row0_col15,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row0_col16,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row1_col2,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row1_col6,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row1_col9,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row1_col10,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row1_col11,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row1_col13,#T_a4706d8e_46ca_11eb_a6f0_0242ac1c0002row1_col14{
#             background-color:  #ffff66;
#             color:  #000000;
# ...

# %%
data['Initial'].replace(['Mlle', 'Mme', 'Ms', 'Dr', 'Major', 'Lady','Countess', 
                         'Jonkheer', 'Col', 'Rev', 'Capt', 'Sir', 'Don'],
                        ['Miss', 'Miss', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mrs', 
                         'Other', 'Other', 'Other', 'Mr', 'Mr', 'Mr'], inplace=True )

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
# Fill  NaN Ages 

data.loc[(data.Age.isnull()) & (data.Initial=='Mr'), 'Age']= 33
data.loc[(data.Age.isnull()) & (data.Initial=='Mrs'), 'Age']=36
data.loc[(data.Age.isnull()) & (data.Initial=='Master'), 'Age']=5
data.loc[(data.Age.isnull()) & (data.Initial=='Miss'), 'Age']=22
data.loc[(data.Age.isnull()) & (data.Initial=='Other'), 'Age']=46

# %%
data.Age.isnull().any()
# Out:
# False

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0], bins=20, 
                                        edgecolor='black', color='red')
ax[0].set_title('Survived=0')
x1=list(range(0, 85, 5))
ax[0].set_xticks(x1)

data[data['Survived']==1].Age.plot.hist(ax=ax[1], color='green',
                                        bins=20, edgecolor='black')
ax[1].set_title('Survived=1')
x2 = list(range(0, 85, 5))
ax[1].set_xticks(x2)
plt.show()
