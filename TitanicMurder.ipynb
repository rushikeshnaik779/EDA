# %% [markdown]
# <a href="https://colab.research.google.com/github/rushikeshnaik779/EDA/blob/master/TitanicMurder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - this EDA is not my work it is compilation of Number of kernels
# - this EDA is totally made for learning purpose

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os 
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"

# %%
# %cd /content/gdrive/MyDrive/Kaggle
# Out:
# /content/gdrive/MyDrive/Kaggle

# %%
# !kaggle competitions download -c titanic
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.10 / client 1.5.4)
# gender_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# train.csv: Skipping, found more recently modified local copy (use --force to force download)
# test.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip \*.zip && rm *.zip
# Out:
# unzip:  cannot find or open *.zip, *.zip.zip or *.zip.ZIP.
#
# No zipfiles found.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
# %ls
# Out:
# gender_submission.csv  kaggle.json  test.csv  train.csv

# %%
data = pd.read_csv('./train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
data.isnull().sum() # checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Question comes how many survived  

f, ax = plt.subplots(1, 2, figsize=(18, 8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1], autopct = '%1.1f%%',
                                         ax=ax[0], shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=data, ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
# Analysing the features
#SEX ---> CATEGORICAL FEATURE

data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 8))
data[['Sex', 'Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
# PCLASS ---> Ordinal feature

pd.crosstab(data.Pclass, data.Survived, margins=True).style.background_gradient(
    cmap='summer_r'
)
# Out:
# <style  type="text/css" >
# #T_ed600c3e_478d_11eb_a246_0242ac1c0002row0_col0,#T_ed600c3e_478d_11eb_a246_0242ac1c0002row1_col1,#T_ed600c3e_478d_11eb_a246_0242ac1c0002row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_ed600c3e_478d_11eb_a246_0242ac1c0002row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_ed600c3e_478d_11eb_a246_0242ac1c0002row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_ed600c3e_478d_11eb_a246_0242ac1c0002row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_ed600c3e_478d_11eb_a246_0242ac1c0002row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_ed600c3e_478d_11eb_a246_0242ac1c0002row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_ed600c3e_478d_11eb_a246_0242ac1c0002row2_col2{
#             background-color:  #90c866;
#             color:  #000000;
#         }#T_ed600c3e_478d_11eb_a246_0242ac1c0002row3_col0,#T_ed600c3e_478d_11eb_a246_0242ac1c0002row3_col1,#T_ed600c3e_478d_11eb_a246_0242ac1c0002row3_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_ed600c3e_478d_11eb_a246_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ed600c3e_478d_11eb_a246_0242ac1c0002level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_ed600c3e_478d_11eb_a246_0242ac1c0002row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_ed600c3e_478d_11eb_a246_0242ac1c0002row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_ed600c3e_478d_11eb_a246_0242ac1c0002row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_ed600c3e_478d_11eb_a246_0242ac1c0002level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_ed600c3e_478d_11eb_a246_0242ac1c0002row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_ed600c3e_478d_11eb_a246_0242ac1c0002row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_ed600c3e_478d_11eb_a246_0242ac1c0002row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_ed600c3e_478d_11eb_a246_0242ac1c0002level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_ed600c3e_478d_11eb_a246_0242ac1c0002row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_ed600c3e_478d_11eb_a246_0242ac1c0002row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_ed600c3e_478d_11eb_a246_0242ac1c0002row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_ed600c3e_478d_11eb_a246_0242ac1c0002level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_ed600c3e_478d_11eb_a246_0242ac1c0002row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_ed600c3e_478d_11eb_a246_0242ac1c0002row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_ed600c3e_478d_11eb_a246_0242ac1c0002row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
data['Pclass'].value_counts().plot.bar(ax=ax[0])
ax[0].set_title('Number of passengers by pclass')
ax[0].set_ylabel('Count')

sns.countplot('Pclass', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead')
# Out:
# Text(0.5, 1.0, 'Pclass: Survived vs Dead')

# %%
pd.crosstab([data.Sex, data.Survived], data.Pclass,
            margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_0b2fb200_478e_11eb_a246_0242ac1c0002row0_col0,#T_0b2fb200_478e_11eb_a246_0242ac1c0002row0_col1,#T_0b2fb200_478e_11eb_a246_0242ac1c0002row0_col3,#T_0b2fb200_478e_11eb_a246_0242ac1c0002row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_0b2fb200_478e_11eb_a246_0242ac1c0002row0_col2,#T_0b2fb200_478e_11eb_a246_0242ac1c0002row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_0b2fb200_478e_11eb_a246_0242ac1c0002row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_0b2fb200_478e_11eb_a246_0242ac1c0002row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_0b2fb200_478e_11eb_a246_0242ac1c0002row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_0b2fb200_478e_11eb_a246_0242ac1c0002row2_col0{
#             background-color:  #a7d366;
#             color:  #000000;
#         }#T_0b2fb200_478e_11eb_a246_0242ac1c0002row2_col1,#T_0b2fb200_478e_11eb_a246_0242ac1c0002row2_col3{
#             background-color:  #85c266;
#             color:  #000000;
#         }#T_0b2fb200_478e_11eb_a246_0242ac1c0002row2_col2{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_0b2fb200_478e_11eb_a246_0242ac1c0002row3_col0{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_0b2fb200_478e_11eb_a246_0242ac1c0002row3_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_0b2fb200_478e_11eb_a246_0242ac1c0002row3_col3{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_0b2fb200_478e_11eb_a246_0242ac1c0002row4_col0,#T_0b2fb200_478e_11eb_a246_0242ac1c0002row4_col1,#T_0b2fb200_478e_11eb_a246_0242ac1c0002row4_col2,#T_0b2fb200_478e_11eb_a246_0242ac1c0002row4_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_0b2fb200_478e_11eb_a246_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0b2fb200_478e_11eb_a246_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_0b2fb200_478e_11eb_a246_0242ac1c0002level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_0b2fb200_478e_11eb_a246_0242ac1c0002level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_0b2fb200_478e_11eb_a246_0242ac1c0002level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_0b2fb200_478e_11eb_a246_0242ac1c0002level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_0b2fb200_478e_11eb_a246_0242ac1c0002level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_0b2fb200_478e_11eb_a246_0242ac1c0002level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_0b2fb200_478e_11eb_a246_0242ac1c0002level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_0b2fb200_478e_11eb_a246_0242ac1c0002row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=data)
plt.show()

# %%
# AGE ---> Continous Feature

print('Oldest Passenger was of:', data['Age'].max(), 'Years')
print('Youngest Passenger was of:', data['Age'].min(), 'Years')
print('Average Age on the ship was : ',data['Age'].mean(), 'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship was :  29.69911764705882 Years

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 8))
sns.violinplot("Pclass", "Age", hue="Survived", data=data, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))

sns.violinplot("Sex", "Age", hue="Survived", data=data,
               split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %%
data['Initial'] = 0
for i in data:
  data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')

# %%
data.Initial.value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Mlle          2
# Col           2
# Mme           1
# Don           1
# Sir           1
# Jonkheer      1
# Lady          1
# Ms            1
# Capt          1
# Countess      1
# Name: Initial, dtype: int64

# %%
pd.crosstab(data.Initial, data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_25edff20_478e_11eb_a246_0242ac1c0002row0_col0,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col1,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col3,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col4,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col5,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col7,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col8,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col12,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col15,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col16,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col2,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col6,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col9,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col10,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col11,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col13,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col14{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col2,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col6,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col9,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col10,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col11,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col13,#T_25edff20_478e_11eb_a246_0242ac1c0002row0_col14,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col0,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col1,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col3,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col4,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col5,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col7,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col8,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col12,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col15,#T_25edff20_478e_11eb_a246_0242ac1c0002row1_col16{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_25edff20_478e_11eb_a246_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_25edff20_478e_11eb_a246_0242ac1c0002level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col9" class="data row0 col9" >182</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col10" class="data row0 col10" >2</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col11" class="data row0 col11" >1</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col13" class="data row0 col13" >125</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col14" class="data row0 col14" >1</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col15" class="data row0 col15" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row0_col16" class="data row0 col16" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_25edff20_478e_11eb_a246_0242ac1c0002level0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col4" class="data row1 col4" >6</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col5" class="data row1 col5" >1</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col6" class="data row1 col6" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col7" class="data row1 col7" >2</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col8" class="data row1 col8" >40</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col9" class="data row1 col9" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col10" class="data row1 col10" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col11" class="data row1 col11" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col12" class="data row1 col12" >517</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col13" class="data row1 col13" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col14" class="data row1 col14" >0</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col15" class="data row1 col15" >6</td>
#                         <td id="T_25edff20_478e_11eb_a246_0242ac1c0002row1_col16" class="data row1 col16" >1</td>
#             </tr>
#     </tbody></table>

# %%
data['Initial'].replace(['Mlle', 'Mme', 'Ms', 'Dr', 'Major', 'Lady','Countess', 
                         'Jonkheer', 'Col', 'Rev', 'Capt', 'Sir', 'Don'],
                        ['Miss', 'Miss', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mrs', 
                         'Other', 'Other', 'Other', 'Mr', 'Mr', 'Mr'], inplace=True )

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
# Fill  NaN Ages 

data.loc[(data.Age.isnull()) & (data.Initial=='Mr'), 'Age']= 33
data.loc[(data.Age.isnull()) & (data.Initial=='Mrs'), 'Age']=36
data.loc[(data.Age.isnull()) & (data.Initial=='Master'), 'Age']=5
data.loc[(data.Age.isnull()) & (data.Initial=='Miss'), 'Age']=22
data.loc[(data.Age.isnull()) & (data.Initial=='Other'), 'Age']=46

# %%
data.Age.isnull().any()
# Out:
# False

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0], bins=20, 
                                        edgecolor='black', color='red')
ax[0].set_title('Survived=0')
x1=list(range(0, 85, 5))
ax[0].set_xticks(x1)

data[data['Survived']==1].Age.plot.hist(ax=ax[1], color='green',
                                        bins=20, edgecolor='black')
ax[1].set_title('Survived=1')
x2 = list(range(0, 85, 5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass', 'Survived', col='Initial', data=data)
plt.show()

# %%
data['Embarked'].fillna('S', inplace=True)

# %%
data.Embarked.isnull().any()
# Out:
# False

# %%
# SibSip means wheather is person is with his family or alone 
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_f04d7822_478e_11eb_a246_0242ac1c0002row0_col0,#T_f04d7822_478e_11eb_a246_0242ac1c0002row0_col1{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_f04d7822_478e_11eb_a246_0242ac1c0002row1_col0{
#             background-color:  #c4e266;
#             color:  #000000;
#         }#T_f04d7822_478e_11eb_a246_0242ac1c0002row1_col1{
#             background-color:  #77bb66;
#             color:  #000000;
#         }#T_f04d7822_478e_11eb_a246_0242ac1c0002row2_col0,#T_f04d7822_478e_11eb_a246_0242ac1c0002row4_col0{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_f04d7822_478e_11eb_a246_0242ac1c0002row2_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_f04d7822_478e_11eb_a246_0242ac1c0002row3_col0,#T_f04d7822_478e_11eb_a246_0242ac1c0002row3_col1{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_f04d7822_478e_11eb_a246_0242ac1c0002row4_col1{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_f04d7822_478e_11eb_a246_0242ac1c0002row5_col0,#T_f04d7822_478e_11eb_a246_0242ac1c0002row5_col1,#T_f04d7822_478e_11eb_a246_0242ac1c0002row6_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_f04d7822_478e_11eb_a246_0242ac1c0002row6_col0{
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_f04d7822_478e_11eb_a246_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f04d7822_478e_11eb_a246_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row0_col0" class="data row0 col0" >398</td>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row0_col1" class="data row0 col1" >210</td>
#             </tr>
#             <tr>
#                         <th id="T_f04d7822_478e_11eb_a246_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row1_col1" class="data row1 col1" >112</td>
#             </tr>
#             <tr>
#                         <th id="T_f04d7822_478e_11eb_a246_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row2_col1" class="data row2 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_f04d7822_478e_11eb_a246_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row3_col0" class="data row3 col0" >12</td>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row3_col1" class="data row3 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_f04d7822_478e_11eb_a246_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row4_col0" class="data row4 col0" >15</td>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row4_col1" class="data row4 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_f04d7822_478e_11eb_a246_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f04d7822_478e_11eb_a246_0242ac1c0002level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_f04d7822_478e_11eb_a246_0242ac1c0002row6_col1" class="data row6 col1" >0</td>
#             </tr>
#     </tbody></table>

# %%
sns.barplot('SibSp','Survived',data=data)
ax.set_title('SibSp vs Survived')
plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_13503f9c_4791_11eb_a246_0242ac1c0002row0_col0,#T_13503f9c_4791_11eb_a246_0242ac1c0002row0_col1,#T_13503f9c_4791_11eb_a246_0242ac1c0002row0_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_13503f9c_4791_11eb_a246_0242ac1c0002row1_col0{
#             background-color:  #7bbd66;
#             color:  #000000;
#         }#T_13503f9c_4791_11eb_a246_0242ac1c0002row1_col1{
#             background-color:  #8ac466;
#             color:  #000000;
#         }#T_13503f9c_4791_11eb_a246_0242ac1c0002row1_col2{
#             background-color:  #c6e266;
#             color:  #000000;
#         }#T_13503f9c_4791_11eb_a246_0242ac1c0002row2_col0,#T_13503f9c_4791_11eb_a246_0242ac1c0002row4_col2{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_13503f9c_4791_11eb_a246_0242ac1c0002row2_col1{
#             background-color:  #eef666;
#             color:  #000000;
#         }#T_13503f9c_4791_11eb_a246_0242ac1c0002row2_col2{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_13503f9c_4791_11eb_a246_0242ac1c0002row3_col0,#T_13503f9c_4791_11eb_a246_0242ac1c0002row3_col2{
#             background-color:  #fafc66;
#             color:  #000000;
#         }#T_13503f9c_4791_11eb_a246_0242ac1c0002row3_col1{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }#T_13503f9c_4791_11eb_a246_0242ac1c0002row4_col0,#T_13503f9c_4791_11eb_a246_0242ac1c0002row4_col1,#T_13503f9c_4791_11eb_a246_0242ac1c0002row5_col0,#T_13503f9c_4791_11eb_a246_0242ac1c0002row5_col1,#T_13503f9c_4791_11eb_a246_0242ac1c0002row5_col2,#T_13503f9c_4791_11eb_a246_0242ac1c0002row6_col0,#T_13503f9c_4791_11eb_a246_0242ac1c0002row6_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_13503f9c_4791_11eb_a246_0242ac1c0002row6_col2{
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_13503f9c_4791_11eb_a246_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_13503f9c_4791_11eb_a246_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row0_col0" class="data row0 col0" >137</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row0_col1" class="data row0 col1" >120</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row0_col2" class="data row0 col2" >351</td>
#             </tr>
#             <tr>
#                         <th id="T_13503f9c_4791_11eb_a246_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row1_col0" class="data row1 col0" >71</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row1_col1" class="data row1 col1" >55</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row1_col2" class="data row1 col2" >83</td>
#             </tr>
#             <tr>
#                         <th id="T_13503f9c_4791_11eb_a246_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row2_col0" class="data row2 col0" >5</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row2_col1" class="data row2 col1" >8</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row2_col2" class="data row2 col2" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_13503f9c_4791_11eb_a246_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row3_col1" class="data row3 col1" >1</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row3_col2" class="data row3 col2" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_13503f9c_4791_11eb_a246_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row4_col2" class="data row4 col2" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_13503f9c_4791_11eb_a246_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_13503f9c_4791_11eb_a246_0242ac1c0002level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_13503f9c_4791_11eb_a246_0242ac1c0002row6_col2" class="data row6 col2" >7</td>
#             </tr>
#     </tbody></table>

# %%
sns.barplot('Parch','Survived',data=data)
plt.title('Parch vs Survived')
plt.show()

# %%
sns.factorplot('Parch', 'Survived', data=data)
plt.title('Parch vs Survived')
plt.show()

# %%
# FARE---------> Continous Feature 

print('Highest Fare was:', data['Fare'].max())
print('Lowest Fare was : ',data['Fare'].min())
print('Average Fare was : ',data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was :  0.0
# Average Fare was :  32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# ### Comparison between Features

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# Interpreting The Heatmap
# The first thing to note is that only the numeric features are compared as it is obvious that we cannot correlate between alphabets or strings. Before understanding the plot, let us see what exactly correlation is.
#
# POSITIVE CORRELATION: If an increase in feature A leads to increase in feature B, then they are positively correlated. A value 1 means perfect positive correlation.
#
# NEGATIVE CORRELATION: If an increase in feature A leads to decrease in feature B, then they are negatively correlated. A value -1 means perfect negative correlation.
#
# Now lets say that two features are highly or perfectly correlated, so the increase in one leads to increase in the other. This means that both the features are containing highly similar information and there is very little or no variance in information. This is known as MultiColinearity as both of them contains almost the same information.
#
# So do you think we should use both of them as one of them is redundant. While making or training models, we should try to eliminate redundant features as it reduces training time and many such advantages.
#
# Now from the above heatmap,we can see that the features are not much correlated. The highest correlation is between SibSp and Parch i.e 0.41. So we can carry on with all features.
